# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.callbacks import Callback

from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import KFold, StratifiedKFold
from sklearn import metrics

from time import time

# %%
# %%time
PATH_STORE = '../saved/storage.h5'
train_pd = pd.read_hdf(PATH_STORE, 'train')
# Out:
# CPU times: user 133 ms, sys: 2.03 s, total: 2.17 s
# Wall time: 1min 3s

# %%
import random
rows = random.sample(train_pd.index, 10000)
df = train_pd.ix[rows]
df.fillna(0, inplace=True)

# %%
from keras.layers.advanced_activations import ParametricSoftplus, PReLU
from keras.optimizers import Adadelta, Adagrad, Adam, RMSprop
def build_model(input_dim, output_dim):
    size_hid = 1024*1
    
    model = Sequential()
    model.add(Dense(input_dim, size_hid, init='lecun_uniform'))
#     model.add(Activation('relu'))
    model.add(ParametricSoftplus(size_hid))
    model.add(Dropout(0.5))

    model.add(Dense(size_hid, size_hid, init='lecun_uniform'))
#     model.add(Activation('relu'))
    model.add(ParametricSoftplus(size_hid))
    model.add(Dropout(0.5))
    
    model.add(Dense(size_hid, size_hid, init='lecun_uniform'))
#     model.add(Activation('relu'))
    model.add(ParametricSoftplus(size_hid))
    model.add(Dropout(0.5))
    
    model.add(Dense(size_hid, size_hid, init='lecun_uniform'))
#     model.add(Activation('relu'))
    model.add(ParametricSoftplus(size_hid))
    model.add(Dropout(0.5))

    model.add(Dense(size_hid, output_dim, init='lecun_uniform'))
    model.add(Activation('softmax'))

    opt = RMSprop(lr=0.0005, rho=0.75, epsilon=1e-6)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    return model

# %%
# %%time
y = df['target']
Y = np_utils.to_categorical(y)
df.drop(['target'], axis=1, inplace=True)
X = np.array(df)
X = X.astype(np.float32)

scaler = StandardScaler()
X = scaler.fit_transform(X)
# Out:
# CPU times: user 1.73 s, sys: 470 ms, total: 2.2 s
# Wall time: 2.16 s

# %%
# X = X[:, X.max(axis=0) < 1]
print X.shape
# Out:
# (10000, 2152)

# %%
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        pass
        
    def on_epoch_end(self, epoch, logs={}):
        self.losses.append(logs.get('val_loss'))

# %%
input_dim = X.shape[1]
output_dim = Y.shape[1]

k = 4
skf = StratifiedKFold(y, n_folds=k,)
scores = []
losses = []
f = 0
for train, valid in skf:
    tic = time()
    print('---'*20)
    print('Fold', f)
    print('---'*20)
    f += 1
    X_train = X[train]
    X_valid = X[valid]
    Y_train = Y[train]
    Y_valid = Y[valid]
    y_valid = np.array(y)[valid]
    
    history = LossHistory()

    print("Building model...")
    model = build_model(input_dim, output_dim)

    print("Training model...")

    model.fit(X_train, Y_train, nb_epoch=100, batch_size=1024*4, 
              validation_data=(X_valid, Y_valid),
              callbacks=[history],
              verbose=2)
    valid_preds = model.predict_proba(X_valid, batch_size=1024*16, verbose=0)
    valid_preds = valid_preds[:, 1]
    roc = metrics.roc_auc_score(y_valid, valid_preds)
    print("ROC:", roc)
    
    scores.append(roc)
    losses.append(history.losses)
    
    toc = time() - tic
    print 'Time: %g sec' % toc

print('Average ROC:', np.mean(scores))
# Out:
# ------------------------------------------------------------
# ('Fold', 0)
# ------------------------------------------------------------
# Building model...
# Training model...
# Train on 7499 samples, validate on 2501 samples
# Epoch 0
# 0s - loss: 0.6185 - val_loss: 0.5531
# Epoch 1
# 0s - loss: 0.5536 - val_loss: 0.5474
# Epoch 2
# 0s - loss: 0.5506 - val_loss: 0.5459
# Epoch 3
# 0s - loss: 0.5507 - val_loss: 0.5444
# Epoch 4
# 0s - loss: 0.5484 - val_loss: 0.5446
# Epoch 5
# 0s - loss: 0.5464 - val_loss: 0.5427
# Epoch 6
# 0s - loss: 0.5460 - val_loss: 0.5448
# Epoch 7
# 0s - loss: 0.5447 - val_loss: 0.5411
# Epoch 8
# 0s - loss: 0.5450 - val_loss: 0.5453
# Epoch 9
# 0s - loss: 0.5461 - val_loss: 0.5433
# Epoch 10
# 0s - loss: 0.5418 - val_loss: 0.5390
# Epoch 11
# 0s - loss: 0.5410 - val_loss: 0.5378
# Epoch 12
# 0s - loss: 0.5404 - val_loss: 0.5365
# Epoch 13
# 0s - loss: 0.5394 - val_loss: 0.5351
# Epoch 14
# 0s - loss: 0.5372 - val_loss: 0.5337
# Epoch 15
# 0s - loss: 0.5358 - val_loss: 0.5325
# Epoch 16
# 0s - loss: 0.5341 - val_loss: 0.5306
# Epoch 17
# 0s - loss: 0.5319 - val_loss: 0.5287
# Epoch 18
# 0s - loss: 0.5321 - val_loss: 0.5267
# Epoch 19
# 0s - loss: 0.5286 - val_loss: 0.5244
# Epoch 20
# 0s - loss: 0.5259 - val_loss: 0.5223
# Epoch 21
# 0s - loss: 0.5225 - val_loss: 0.5209
# Epoch 22
# 0s - loss: 0.5216 - val_loss: 0.5194
# Epoch 23
# 0s - loss: 0.5183 - val_loss: 0.5175
# Epoch 24
# 0s - loss: 0.5173 - val_loss: 0.5152
# Epoch 25
# 0s - loss: 0.5120 - val_loss: 0.5149
# Epoch 26
# 0s - loss: 0.5106 - val_loss: 0.5129
# Epoch 27
# 0s - loss: 0.5106 - val_loss: 0.5119
# Epoch 28
# 0s - loss: 0.5078 - val_loss: 0.5093
# Epoch 29
# 0s - loss: 0.5072 - val_loss: 0.5120
# Epoch 30
# 0s - loss: 0.5074 - val_loss: 0.5065
# Epoch 31
# 0s - loss: 0.5016 - val_loss: 0.5025
# Epoch 32
# 0s - loss: 0.4983 - val_loss: 0.5044
# Epoch 33
# 0s - loss: 0.4972 - val_loss: 0.5026
# Epoch 34
# 0s - loss: 0.4957 - val_loss: 0.5001
# Epoch 35
# 0s - loss: 0.4927 - val_loss: 0.4977
# Epoch 36
# 0s - loss: 0.4893 - val_loss: 0.4960
# Epoch 37
# 0s - loss: 0.4922 - val_loss: 0.4950
# Epoch 38
# 0s - loss: 0.4874 - val_loss: 0.4950
# Epoch 39
# 0s - loss: 0.4870 - val_loss: 0.4933
# Epoch 40
# 0s - loss: 0.4844 - val_loss: 0.4930
# Epoch 41
# 0s - loss: 0.4819 - val_loss: 0.4941
# Epoch 42
# 0s - loss: 0.4842 - val_loss: 0.4922
# Epoch 43
# Epoch 90
# 0s - loss: 0.3938 - val_loss: 0.5427
# Epoch 91
# 0s - loss: 0.3957 - val_loss: 0.5332
# Epoch 92
# 0s - loss: 0.3823 - val_loss: 0.5356
# Epoch 93
# 0s - loss: 0.3795 - val_loss: 0.5437
# Epoch 94
# 0s - loss: 0.3747 - val_loss: 0.5591
# Epoch 95
# 0s - loss: 0.4014 - val_loss: 0.5773
# Epoch 96
# 0s - loss: 0.4016 - val_loss: 0.5376
# Epoch 97
# 0s - loss: 0.3706 - val_loss: 0.5322
# Epoch 98
# 0s - loss: 0.3663 - val_loss: 0.5381
# Epoch 99
# 0s - loss: 0.3697 - val_loss: 0.5563
# ('ROC:', 0.67468966930733654)
# Time: 50.4345 sec
# ------------------------------------------------------------
# ('Fold', 1)
# ------------------------------------------------------------
# Building model...
# Training model...
# Train on 7500 samples, validate on 2500 samples
# Epoch 0
# 0s - loss: 0.6484 - val_loss: 0.5566
# Epoch 1
# 0s - loss: 0.5535 - val_loss: 0.5487
# Epoch 2
# 0s - loss: 0.5518 - val_loss: 0.5468
# Epoch 3
# 0s - loss: 0.5511 - val_loss: 0.5465
# Epoch 4
# 0s - loss: 0.5479 - val_loss: 0.5441
# Epoch 5
# 0s - loss: 0.5472 - val_loss: 0.5451
# Epoch 6
# 0s - loss: 0.5462 - val_loss: 0.5433
# Epoch 7
# 0s - loss: 0.5450 - val_loss: 0.5408
# Epoch 8
# 0s - loss: 0.5441 - val_loss: 0.5401
# Epoch 9
# 0s - loss: 0.5455 - val_loss: 0.5383
# Epoch 10
# 0s - loss: 0.5449 - val_loss: 0.5373
# Epoch 11
# 0s - loss: 0.5433 - val_loss: 0.5368
# Epoch 12
# 0s - loss: 0.5406 - val_loss: 0.5362
# Epoch 13
# 0s - loss: 0.5390 - val_loss: 0.5360
# Epoch 14
# 0s - loss: 0.5388 - val_loss: 0.5323
# Epoch 15
# 0s - loss: 0.5359 - val_loss: 0.5307
# Epoch 16
# 0s - loss: 0.5378 - val_loss: 0.5288
# Epoch 17
# 0s - loss: 0.5373 - val_loss: 0.5269
# Epoch 18
# 0s - loss: 0.5328 - val_loss: 0.5263
# Epoch 19
# 0s - loss: 0.5302 - val_loss: 0.5255
# Epoch 20
# 0s - loss: 0.5281 - val_loss: 0.5200
# Epoch 21
# 0s - loss: 0.5261 - val_loss: 0.5182
# Epoch 22
# 0s - loss: 0.5242 - val_loss: 0.5151
# Epoch 23
# 0s - loss: 0.5224 - val_loss: 0.5130
# Epoch 24
# 0s - loss: 0.5194 - val_loss: 0.5112
# Epoch 25
# 0s - loss: 0.5175 - val_loss: 0.5076
# Epoch 26
# 0s - loss: 0.5141 - val_loss: 0.5061
# Epoch 27
# 0s - loss: 0.5120 - val_loss: 0.5044
# Epoch 28
# 0s - loss: 0.5099 - val_loss: 0.5010
# Epoch 29
# 0s - loss: 0.5112 - val_loss: 0.5002
# Epoch 30
# 0s - loss: 0.5060 - val_loss: 0.5014
# Epoch 31
# 0s - loss: 0.5089 - val_loss: 0.5064
# Epoch 32
# 0s - loss: 0.5040 - val_loss: 0.4977
# Epoch 33
# 0s - loss: 0.4398 - val_loss: 0.5179
# Epoch 80
# 0s - loss: 0.4316 - val_loss: 0.4980
# Epoch 81
# 0s - loss: 0.4100 - val_loss: 0.4946
# Epoch 82
# 0s - loss: 0.4128 - val_loss: 0.5118
# Epoch 83
# 0s - loss: 0.4253 - val_loss: 0.5146
# Epoch 84
# 0s - loss: 0.4191 - val_loss: 0.5059
# Epoch 85
# 0s - loss: 0.4069 - val_loss: 0.5063
# Epoch 86
# 0s - loss: 0.4022 - val_loss: 0.5135
# Epoch 87
# 0s - loss: 0.4040 - val_loss: 0.5136
# Epoch 88
# 0s - loss: 0.3996 - val_loss: 0.5107
# Epoch 89
# 0s - loss: 0.3954 - val_loss: 0.5202
# Epoch 90
# 0s - loss: 0.4029 - val_loss: 0.5244
# Epoch 91
# 0s - loss: 0.4007 - val_loss: 0.5207
# Epoch 92
# 0s - loss: 0.4016 - val_loss: 0.5468
# Epoch 93
# 0s - loss: 0.4160 - val_loss: 0.5308
# Epoch 94
# 0s - loss: 0.3973 - val_loss: 0.5167
# Epoch 95
# 0s - loss: 0.3824 - val_loss: 0.5252
# Epoch 96
# 0s - loss: 0.3856 - val_loss: 0.5327
# Epoch 97
# 0s - loss: 0.3823 - val_loss: 0.5305
# Epoch 98
# 0s - loss: 0.3740 - val_loss: 0.5394
# Epoch 99
# 0s - loss: 0.3673 - val_loss: 0.5437
# ('ROC:', 0.73125393318604803)
# Time: 50.2362 sec
# ------------------------------------------------------------
# ('Fold', 2)
# ------------------------------------------------------------
# Building model...
# Training model...
# Train on 7500 samples, validate on 2500 samples
# Epoch 0
# 0s - loss: 0.6473 - val_loss: 0.5553
# Epoch 1
# 0s - loss: 0.5561 - val_loss: 0.5492
# Epoch 2
# 0s - loss: 0.5517 - val_loss: 0.5462
# Epoch 3
# 0s - loss: 0.5498 - val_loss: 0.5470
# Epoch 4
# 0s - loss: 0.5496 - val_loss: 0.5450
# Epoch 5
# 0s - loss: 0.5482 - val_loss: 0.5445
# Epoch 6
# 0s - loss: 0.5468 - val_loss: 0.5430
# Epoch 7
# 0s - loss: 0.5458 - val_loss: 0.5428
# Epoch 8
# 0s - loss: 0.5448 - val_loss: 0.5422
# Epoch 9
# 0s - loss: 0.5433 - val_loss: 0.5410
# Epoch 10
# 0s - loss: 0.5434 - val_loss: 0.5430
# Epoch 11
# 0s - loss: 0.5449 - val_loss: 0.5437
# Epoch 12
# 0s - loss: 0.5427 - val_loss: 0.5418
# Epoch 13
# 0s - loss: 0.5415 - val_loss: 0.5389
# Epoch 14
# 0s - loss: 0.5386 - val_loss: 0.5384
# Epoch 15
# 0s - loss: 0.5379 - val_loss: 0.5366
# Epoch 16
# 0s - loss: 0.5353 - val_loss: 0.5354
# Epoch 17
# 0s - loss: 0.5342 - val_loss: 0.5335
# Epoch 18
# 0s - loss: 0.5324 - val_loss: 0.5320
# Epoch 19
# 0s - loss: 0.5318 - val_loss: 0.5336
# Epoch 20
# 0s - loss: 0.5282 - val_loss: 0.5264
# Epoch 21
# 0s - loss: 0.5248 - val_loss: 0.5240
# Epoch 22
# 0s - loss: 0.5219 - val_loss: 0.5214
# Epoch 23
# 0s - loss: 0.5220 - val_loss: 0.5195
# Epoch 24
# 0s - loss: 0.5178 - val_loss: 0.5175
# Epoch 25
# 0s - loss: 0.5162 - val_loss: 0.5163
# Epoch 26
# 0s - loss: 0.5137 - val_loss: 0.5145
# Epoch 27
# 0s - loss: 0.5103 - val_loss: 0.5131
# Epoch 28
# 0s - loss: 0.5091 - val_loss: 0.5125
# Epoch 29
# 0s - loss: 0.5078 - val_loss: 0.5108
# Epoch 30
# 0s - loss: 0.5038 - val_loss: 0.5097
# Epoch 31
# 0s - loss: 0.5034 - val_loss: 0.5089
# Epoch 32
# 0s - loss: 0.4996 - val_loss: 0.5078
# Epoch 33
# 0s - loss: 0.4992 - val_loss: 0.5071
# Epoch 34
# 0s - loss: 0.4945 - val_loss: 0.5057
# Epoch 35
# 0s - loss: 0.4931 - val_loss: 0.5051
# Epoch 36
# 0s - loss: 0.4951 - val_loss: 0.5063
# Epoch 37
# 0s - loss: 0.4941 - val_loss: 0.5030
# Epoch 38
# 0s - loss: 0.4861 - val_loss: 0.5021
# Epoch 39
# 0s - loss: 0.4877 - val_loss: 0.5012
# Epoch 40
# 0s - loss: 0.4850 - val_loss: 0.5010
# Epoch 41
# 0s - loss: 0.4800 - val_loss: 0.5006
# Epoch 42
# 0s - loss: 0.4787 - val_loss: 0.5044
# Epoch 43
# 0s - loss: 0.4839 - val_loss: 0.5065
# Epoch 44
# 0s - loss: 0.4830 - val_loss: 0.5011
# Epoch 45
# 0s - loss: 0.4747 - val_loss: 0.4987
# Epoch 46
# 0s - loss: 0.4738 - val_loss: 0.4987
# Epoch 47
# 0s - loss: 0.4711 - val_loss: 0.4981
# Epoch 48
# 0s - loss: 0.4738 - val_loss: 0.5045
# Epoch 49
# 0s - loss: 0.4718 - val_loss: 0.4999
# Epoch 50
# 0s - loss: 0.4681 - val_loss: 0.4989
# Epoch 51
# 0s - loss: 0.4665 - val_loss: 0.5007
# Epoch 52
# 0s - loss: 0.4643 - val_loss: 0.4955
# Epoch 53
# 0s - loss: 0.4585 - val_loss: 0.4980
# Epoch 54
# 0s - loss: 0.4626 - val_loss: 0.5032
# Epoch 55
# 0s - loss: 0.4644 - val_loss: 0.5029
# Epoch 56
# 0s - loss: 0.4576 - val_loss: 0.4991
# Epoch 57
# 0s - loss: 0.4539 - val_loss: 0.4991
# Epoch 58
# 0s - loss: 0.4541 - val_loss: 0.5001
# Epoch 59
# 0s - loss: 0.4549 - val_loss: 0.5036
# Epoch 60
# 0s - loss: 0.4563 - val_loss: 0.5035
# Epoch 61
# 0s - loss: 0.4507 - val_loss: 0.5037
# Epoch 62
# 0s - loss: 0.4488 - val_loss: 0.5014
# Epoch 63
# 0s - loss: 0.4462 - val_loss: 0.5099
# Epoch 64
# 0s - loss: 0.4503 - val_loss: 0.5042
# Epoch 65
# 0s - loss: 0.4418 - val_loss: 0.5074
# Epoch 66
# 0s - loss: 0.4414 - val_loss: 0.5055
# Epoch 67
# 0s - loss: 0.4362 - val_loss: 0.5033
# Epoch 68
# 0s - loss: 0.4324 - val_loss: 0.5005
# Epoch 69
# 0s - loss: 0.4292 - val_loss: 0.5074
# Epoch 70
# 0s - loss: 0.4403 - val_loss: 0.5233
# Epoch 71
# 0s - loss: 0.4463 - val_loss: 0.5198
# Epoch 72
# 0s - loss: 0.4365 - val_loss: 0.5136
# Epoch 73
# 0s - loss: 0.4273 - val_loss: 0.5058
# Epoch 74
# 0s - loss: 0.4205 - val_loss: 0.5040
# Epoch 75
# 0s - loss: 0.4102 - val_loss: 0.5094
# Epoch 76
# 0s - loss: 0.4098 - val_loss: 0.5094
# Epoch 77
# 0s - loss: 0.4048 - val_loss: 0.5115
# Epoch 78
# 0s - loss: 0.4043 - val_loss: 0.5328
# Epoch 79
# 0s - loss: 0.4296 - val_loss: 0.5550
# Epoch 80
# 0s - loss: 0.4501 - val_loss: 0.5403
# Epoch 81
# 0s - loss: 0.4158 - val_loss: 0.5134
# Epoch 82
# 0s - loss: 0.4088 - val_loss: 0.5296
# Epoch 83
# 0s - loss: 0.4127 - val_loss: 0.5355
# Epoch 84
# 0s - loss: 0.4043 - val_loss: 0.5278
# Epoch 85
# 0s - loss: 0.4024 - val_loss: 0.5238
# Epoch 86
# 0s - loss: 0.3897 - val_loss: 0.5300
# Epoch 87
# 0s - loss: 0.3845 - val_loss: 0.5280
# Epoch 88
# 0s - loss: 0.3797 - val_loss: 0.5440
# Epoch 89
# 0s - loss: 0.3986 - val_loss: 0.5731
# Epoch 90
# 0s - loss: 0.4261 - val_loss: 0.5704
# Epoch 91
# 0s - loss: 0.4091 - val_loss: 0.5366
# Epoch 92
# 0s - loss: 0.3854 - val_loss: 0.5327
# Epoch 93
# 0s - loss: 0.3725 - val_loss: 0.5447
# Epoch 94
# 0s - loss: 0.3839 - val_loss: 0.5709
# Epoch 95
# 0s - loss: 0.4174 - val_loss: 0.5341
# Epoch 96
# 0s - loss: 0.3780 - val_loss: 0.5379
# Epoch 97
# 0s - loss: 0.3764 - val_loss: 0.5446
# Epoch 98
# 0s - loss: 0.3842 - val_loss: 0.5589
# Epoch 99
# 0s - loss: 0.3932 - val_loss: 0.5497
# ('ROC:', 0.69784829617727795)
# Time: 50.232 sec
# ------------------------------------------------------------
# ('Fold', 3)
# ------------------------------------------------------------
# Building model...
# Training model...
# Train on 7501 samples, validate on 2499 samples
# Epoch 0
# 0s - loss: 0.6192 - val_loss: 0.5519
# Epoch 1
# 0s - loss: 0.5517 - val_loss: 0.5477
# Epoch 2
# 0s - loss: 0.5498 - val_loss: 0.5457
# Epoch 3
# 0s - loss: 0.5483 - val_loss: 0.5449
# Epoch 4
# 0s - loss: 0.5483 - val_loss: 0.5452
# Epoch 5
# 0s - loss: 0.5460 - val_loss: 0.5437
# Epoch 6
# 0s - loss: 0.5460 - val_loss: 0.5429
# Epoch 7
# 0s - loss: 0.5468 - val_loss: 0.5450
# Epoch 8
# 0s - loss: 0.5454 - val_loss: 0.5424
# Epoch 9
# 0s - loss: 0.5429 - val_loss: 0.5408
# Epoch 10
# 0s - loss: 0.5431 - val_loss: 0.5387
# Epoch 11
# 0s - loss: 0.5418 - val_loss: 0.5382
# Epoch 12
# 0s - loss: 0.5386 - val_loss: 0.5368
# Epoch 13
# 0s - loss: 0.5415 - val_loss: 0.5361
# Epoch 14
# 0s - loss: 0.5388 - val_loss: 0.5344
# Epoch 15
# 0s - loss: 0.5381 - val_loss: 0.5332
# Epoch 16
# 0s - loss: 0.5362 - val_loss: 0.5315
# Epoch 17
# 0s - loss: 0.5356 - val_loss: 0.5300
# Epoch 18
# 0s - loss: 0.5320 - val_loss: 0.5281
# Epoch 19
# 0s - loss: 0.5306 - val_loss: 0.5258
# Epoch 20
# 0s - loss: 0.5284 - val_loss: 0.5232
# Epoch 21
# 0s - loss: 0.5273 - val_loss: 0.5209
# Epoch 22
# 0s - loss: 0.5238 - val_loss: 0.5187
# Epoch 23
# 0s - loss: 0.5219 - val_loss: 0.5159
# Epoch 24
# 0s - loss: 0.5196 - val_loss: 0.5137
# Epoch 25
# 0s - loss: 0.5164 - val_loss: 0.5141
# Epoch 26
# 0s - loss: 0.5149 - val_loss: 0.5122
# Epoch 27
# 0s - loss: 0.5100 - val_loss: 0.5069
# Epoch 28
# 0s - loss: 0.5085 - val_loss: 0.5050
# Epoch 29
# 0s - loss: 0.5099 - val_loss: 0.5041
# Epoch 30
# 0s - loss: 0.5078 - val_loss: 0.5015
# Epoch 31
# 0s - loss: 0.5050 - val_loss: 0.5002
# Epoch 32
# 0s - loss: 0.5052 - val_loss: 0.4992
# Epoch 33
# 0s - loss: 0.5043 - val_loss: 0.4975
# Epoch 34
# 0s - loss: 0.4995 - val_loss: 0.4955
# Epoch 35
# 0s - loss: 0.4978 - val_loss: 0.4948
# Epoch 36
# 0s - loss: 0.4928 - val_loss: 0.4934
# Epoch 37
# 0s - loss: 0.4944 - val_loss: 0.4917
# Epoch 38
# 0s - loss: 0.4900 - val_loss: 0.4909
# Epoch 39
# 0s - loss: 0.4909 - val_loss: 0.4899
# Epoch 40
# 0s - loss: 0.4893 - val_loss: 0.4911
# Epoch 41
# 0s - loss: 0.4912 - val_loss: 0.4883
# Epoch 42
# 0s - loss: 0.4873 - val_loss: 0.4870
# Epoch 43
# 0s - loss: 0.4830 - val_loss: 0.4862
# Epoch 44
# 0s - loss: 0.4833 - val_loss: 0.4853
# Epoch 45
# 0s - loss: 0.4828 - val_loss: 0.4849
# Epoch 46
# 0s - loss: 0.4831 - val_loss: 0.4859
# Epoch 47
# 0s - loss: 0.4817 - val_loss: 0.4843
# Epoch 48
# 0s - loss: 0.4749 - val_loss: 0.4827
# Epoch 49
# 0s - loss: 0.4767 - val_loss: 0.4863
# Epoch 50
# 0s - loss: 0.4766 - val_loss: 0.4869
# Epoch 51
# 0s - loss: 0.4777 - val_loss: 0.4890
# Epoch 52
# 0s - loss: 0.4757 - val_loss: 0.4850
# Epoch 53
# 0s - loss: 0.4742 - val_loss: 0.4902
# Epoch 54
# 0s - loss: 0.4699 - val_loss: 0.4802
# Epoch 55
# 0s - loss: 0.4625 - val_loss: 0.4799
# Epoch 56
# 0s - loss: 0.4643 - val_loss: 0.4807
# Epoch 57
# 0s - loss: 0.4614 - val_loss: 0.4799
# Epoch 58
# 0s - loss: 0.4631 - val_loss: 0.4971
# Epoch 59
# 0s - loss: 0.4703 - val_loss: 0.4853
# Epoch 60
# 0s - loss: 0.4621 - val_loss: 0.4857
# Epoch 61
# 0s - loss: 0.4564 - val_loss: 0.4829
# Epoch 62
# 0s - loss: 0.4539 - val_loss: 0.4855
# Epoch 63
# 0s - loss: 0.4500 - val_loss: 0.4793
# Epoch 64
# 0s - loss: 0.4453 - val_loss: 0.4813
# Epoch 65
# 0s - loss: 0.4447 - val_loss: 0.4802
# Epoch 66
# 0s - loss: 0.4411 - val_loss: 0.4852
# Epoch 67
# 0s - loss: 0.4411 - val_loss: 0.4915
# Epoch 68
# 0s - loss: 0.4474 - val_loss: 0.4878
# Epoch 69
# 0s - loss: 0.4389 - val_loss: 0.4896
# Epoch 70
# 0s - loss: 0.4486 - val_loss: 0.5021
# Epoch 71
# 0s - loss: 0.4430 - val_loss: 0.4881
# Epoch 72
# 0s - loss: 0.4303 - val_loss: 0.4828
# Epoch 73
# 0s - loss: 0.4269 - val_loss: 0.4890
# Epoch 74
# 0s - loss: 0.4308 - val_loss: 0.4979
# Epoch 75
# 0s - loss: 0.4411 - val_loss: 0.5111
# Epoch 76
# 0s - loss: 0.4395 - val_loss: 0.4959
# Epoch 77
# 0s - loss: 0.4259 - val_loss: 0.5030
# Epoch 78
# 0s - loss: 0.4265 - val_loss: 0.4954
# Epoch 79
# 0s - loss: 0.4207 - val_loss: 0.5014
# Epoch 80
# 0s - loss: 0.4230 - val_loss: 0.4952
# Epoch 81
# 0s - loss: 0.4086 - val_loss: 0.4944
# Epoch 82
# 0s - loss: 0.4065 - val_loss: 0.5031
# Epoch 83
# 0s - loss: 0.4231 - val_loss: 0.5273
# Epoch 84
# 0s - loss: 0.4357 - val_loss: 0.5199
# Epoch 85
# 0s - loss: 0.4258 - val_loss: 0.5091
# Epoch 86
# 0s - loss: 0.4105 - val_loss: 0.5007
# Epoch 87
# 0s - loss: 0.3986 - val_loss: 0.4995
# Epoch 88
# 0s - loss: 0.3989 - val_loss: 0.5165
# Epoch 89
# 0s - loss: 0.4063 - val_loss: 0.5167
# Epoch 90
# 0s - loss: 0.3992 - val_loss: 0.5163
# Epoch 91
# 0s - loss: 0.3983 - val_loss: 0.5280
# Epoch 92
# 0s - loss: 0.4260 - val_loss: 0.5625
# Epoch 93
# 0s - loss: 0.4325 - val_loss: 0.5152
# Epoch 94
# 0s - loss: 0.3887 - val_loss: 0.5119
# Epoch 95
# 0s - loss: 0.3775 - val_loss: 0.5197
# Epoch 96
# 0s - loss: 0.3793 - val_loss: 0.5395
# Epoch 97
# 0s - loss: 0.3856 - val_loss: 0.5334
# Epoch 98
# 0s - loss: 0.3783 - val_loss: 0.5400
# Epoch 99
# 0s - loss: 0.3862 - val_loss: 0.5498
# ('ROC:', 0.71959560235422315)
# Time: 50.4204 sec
# ('Average ROC:', 0.70584687525622147)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(20,10));
print np.array(scores).mean()
print np.array(scores)
plt.plot(np.mean(losses, axis=0), lw=5);
plt.plot(np.array(losses).T, alpha=0.2);
# Out:
# 0.705846875256
# [ 0.67468967  0.73125393  0.6978483   0.7195956 ]
