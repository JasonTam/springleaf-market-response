# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
from scipy.sparse import hstack
import cPickle as pickle

# %%
df = pd.concat([
        pd.concat([pd.read_pickle('./data/train_VAR_0404.p'), 
                   pd.read_pickle('./data/train_VAR_0493.p'),], axis=1),
        pd.concat([pd.read_pickle('./data/test_VAR_0404.p'), 
                   pd.read_pickle('./data/test_VAR_0493.p'),], axis=1)])

df.fillna(0, inplace=True)
df.replace('-1', '', inplace=True)
# df

# %%
vectorizer = CountVectorizer(min_df=4,
    stop_words=['a', 'and', 'for', 'of', 'to'])

combo = df['VAR_0404'].astype(str) + ' ' + df['VAR_0493'].astype(str)
counts_vec = vectorizer.fit_transform(combo)
print counts_vec.shape

# I would store the sparse counts vec in a pandas sparse df, 
# except pandas support for sparse sucks

for col in ['VAR_0404', 'VAR_0493']:
    df[col+'_bool'] = df[col] != ''

occ_feats = hstack([np.array(df[col+'_bool'])[:, None]
                for col in ['VAR_0404', 'VAR_0493']] + [counts_vec])
np.save('./data/occ_feats.npy', occ_feats)
# Out:
# (290463, 730)

# %% [markdown]
# # Scratchspace

# %%
q = []
for k, v in vectorizer.vocabulary_.items():
    q.append([k, counts_vec[:, v].sum()])
    
pd.DataFrame(q).sort(columns=1)
# Out:
#                   0     1
# 176          agency     4
# 28         licensee     4
# 269        cemetery     4
# 245        emblamer     4
# 234      controlled     4
# 224              iv     4
# 222            drug     4
# 203             mgr     4
# 196     anesthetist     4
# 187           alarm     4
# 274            cpas     4
# 65    authorization     4
# 77   rehabilitation     4
# 157     audiologist     4
# 139          safety     4
# 89        pathology     4
# 93           animal     4
# 125       attorneys     4
# 122            ther     4
# 117            food     4
# 110      obstetrics     4
# 172       dispenser     4
# 281        adjuster     4
# 106      gynecology     4
# 324    distribution     4
# 343            phys     4
# 8            charge     4
# 330      associates     4
# 338      osteopathy     4
# 220         license     5
# ..              ...   ...
# 60          firearm   236
# 22      respiratory   238
# 146            care   239
# 344          worker   247
# 295          dental   268
# 46           social   279
# 282        security   279
# 193       therapist   344
# 296          broker   364
# 19      salesperson   408
# 81          nursing   545
# 298      vocational   657
# 306    registration   683
# 113       permanent   684
# 145            card   687
# 198        employee   728
# 131            aide   757
# 191    professional   776
# 305           guard   839
# 201       assistant   865
# 63        certified   961
# 82           estate  1065
# 272            real  1065
# 270        pharmacy  1140
# 218   cosmetologist  1141
# 317      technician  1399
# 299       practical  1880
# 29         licensed  2511
# 315      registered  2579
# 34            nurse  6367
#
# [354 rows x 2 columns]

# %%
df.iloc[list(set(df['VAR_0404'].nonzero()[0]).intersection(set(df['VAR_0493'].nonzero()[0])))]
# Out:
#                               VAR_0404                                VAR_0493
# ID
# 2              CHIEF EXECUTIVE OFFICER           COMMUNITY ASSOCIATION MANAGER
# 168253         INDIVIDUAL - SOLE OWNER                             ELECTRICIAN
# 233890                         CONTACT      REGISTERED ASSOCIATE SOCIAL WORKER
# 130966                        DIRECTOR         CERTIFIED RESPIRATORY THERAPIST
# 130968            PHARMACIST IN CHARGE                              PHARMACIST
# 119185             ACCOUNTS RECEIVABLE                        HOME HEALTH AIDE
# 32179                        PRESIDENT           CERTIFIED BUILDING CONTRACTOR
# 73030                              CEO             CERTIFIED NURSING ASSISTANT
# 262140                          MEMBER                  MANUFACTURING ENGINEER
# 98318                            OWNER                          COSMETOLOGISTS
# 48962     MINIMUM DATA SET COORDINATOR                      PROFESSIONAL NURSE
# 250404                        DIRECTOR                              ACCOUNTANT
# 203915                              DP             CERTIFIED NURSING ASSISTANT
# 102855                         CONTACT      BATON CERT - USED FOR HISTORY ONLY
# 65218                        PRESIDENT                                   GUARD
# 212926                  OFFICE MANAGER                                     LPN
# 250422                           OWNER  MARRIAGE AND FAMILY THERAPIST - INTERN
# 81862                     BOARD MEMBER                        INSURANCE AGENTS
# 151781                  MANAGER/MEMBER                PRIVATE ALARM CONTRACTOR
# 283137                           OWNER                                LICENSED
# 212955                         CONTACT                   ARMED SECURITY GUARDS
# 98373   DIRECTOR INSERVICE TRAINING/ED                        REGISTERED NURSE
# 233991                STAFF PHARMACIST                   REGISTERED PHARMACIST
# 262202                   NEONATOLOGIST                         MEDICAL DOCTORS
# 217741                         CONTACT                      PROFESSIONAL NURSE
# 168390                  VICE PRESIDENT                           COSMETOLOGIST
# 199161                       PRESIDENT      CONTRACTOR CONTROLLING INDIVIDUALS
# 49073                              MRS                        REGISTERED NURSE
# 119313                PHARMACY MANAGER                              PHARMACIST
# 102944                           AGENT                  OCCUPATIONAL THERAPIST
# ...                                ...                                     ...
# 117377                       SECRETARY                    MASTER COSMETOLOGIST
# 102760                       PRESIDENT                           NURSE MIDWIFE
# 135424                PIANO INSTRUCTOR                               COUNSELOR
# 102619                       TREASURER                                   GUARD
# 233733                         PARTNER                           COSMETOLOGIST
# 239187                  OFFICE MANAGER             CERTIFIED PUBLIC ACCOUNTANT
# 4406                         PRESIDENT      CONTRACTOR CONTROLLING INDIVIDUALS
# 147485                       PRESIDENT                   CERTIFIED RESIDENTIAL
# 102669                         CONTACT                           SOCIAL WORKER
# 250226          SENIOR PROJECT MANAGER                    PROFESSINAL ENGINEER
# 179994                        ATTORNEY                                ATTORNEY
# 135503                STAFF PHARMACIST                              PHARMACIST
# 119052                        DIRECTOR                        REGISTERED NURSE
# 81674                        PRESIDENT             CERTIFIED NURSING ASSISTANT
# 262358                           CONTA                        REGISTERED NURSE
# 32459                   MEMBER MANAGER      PHYSICIAN AND SURGEON OR OSTEOPATH
# 233806         CHIEF FINANCIAL OFFICER                          LEGAL SERVICES
# 48829                   MEMBER MANAGER                REAL ESTATE SALES PERSON
# 16129                          CONTACT                             MANICURISTS
# 86413              FAMILY PRACTITIONER                         FAMILY PRACTICE
# 81689                        SECRETARY                        REGISTERED NURSE
# 250278                        ATTORNEY                                ATTORNEY
# 16153                            AGENT                LICENSED PRACTICAL NURSE
# 283002                         MANAGER       REGISTERED CHIROPRACTIC ASSISTANT
# 98226                            AGENT                        REGISTERED NURSE
# 86640                          MANAGER          RESPIRATORY THERAPY TECHNICIAN
# 151659                REGISTERED NURSE                        REGISTERED NURSE
# 196426   CERTIFIED PHARMACY TECHNICIAN                                    TECH
# 64790            PRINCIPAL SHAREHOLDER                    BUILDER - INDIVIDUAL
# 182813                       SECRETARY                        REGISTERED NURSE
#
# [2941 rows x 2 columns]

# %%
counts_vec[0, :]
# Out:
# <1x730 sparse matrix of type '<type 'numpy.int64'>'
# 	with 6 stored elements in Compressed Sparse Row format>
